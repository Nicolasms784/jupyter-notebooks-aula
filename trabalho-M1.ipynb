# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolasms784/jupyter-notebooks-aula/blob/main/trabalho-M1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho M1: Introdução à Programação com Python

# %% [markdown]
# ### Instruções de entrega
#
# 1. Escreva sua resposta **na célula de código logo abaixo de cada questão**. Não apague os enunciados.
# 2. Antes de entregar, execute **todas** as células na ordem (`Runtime -> Run all` / `Kernel -> Restart & Run All`) e **salve o notebook com as saídas visíveis**.
# 3. Não use recursos que ainda não foram estudados em aula.
# 4. Todas as funções pedidas devem ter **docstring** e nomes de variáveis significativos.
# 5. Trabalho **individual**.
#
# ### Critérios de avaliação
#
# | Critério | Peso |
# |---|---|
# | O programa funciona e produz a saída esperada | 50% |
# | Uso correto dos conceitos exigidos pela questão (funções, condicionais, laços, tipos) | 30% |
# | Legibilidade: nomes claros, comentários/docstrings, saída bem formatada | 20% |
#
#
# > **Atenção:** código que não executa (erro de sintaxe) não recebe a pontuação de funcionamento.
# > Se você não conseguir terminar uma questão, entregue a parte que funciona e explique em um comentário o que faltou.
#
# ### Uso de assistentes de IA
#
# O uso de assistentes é permitido para **tirar dúvidas**, mas você deve ser capaz de explicar cada linha do
# seu código. Na última célula do notebook há uma **declaração de uso de IA que deve ser preenchida**.

# %% [markdown]
# ---
#
# ## Parte 1: Variáveis, expressões, tipos e strings (3,0 pontos)

# %% [markdown]
# ### Questão 1: Orçamento de viagem (1,0 ponto)
#
# Escreva um programa que calcule o custo de uma viagem de carro.
#
# O programa deve ler do usuário, usando `input`:
#
# - a distância da viagem, em km (`float`);
# - o consumo médio do carro, em km/litro (`float`);
# - o preço do litro do combustível, em reais (`float`);
# - o valor total dos pedágios, em reais (`float`);
# - o número de pessoas que dividirão a despesa (`int`).
#
# Em seguida o programa deve calcular e exibir:
#
# 1. a quantidade de litros necessária (distância dividida pelo consumo);
# 2. o custo do combustível;
# 3. o custo total (combustível + pedágios);
# 4. o custo por pessoa;
# 5. o tipo (`type`) das variáveis da distância e do número de pessoas.
#
# Todos os valores em reais devem ser exibidos com **2 casas decimais** (use `round` ou formatação de string).
#
# Exemplo:
#
# ```
# Distância da viagem (km): 450
# Consumo médio (km/l): 12.5
# Preço do litro (R$): 5.89
# Total de pedágios (R$): 32.40
# Número de pessoas: 3
#
# Litros necessários: 36.0
# Custo do combustível: R$ 212.04
# Custo total da viagem: R$ 244.44
# Custo por pessoa: R$ 81.48
# Tipo da distância: <class 'float'> | Tipo do número de pessoas: <class 'int'>
# ```

# %%
distancia = float(input("Distância da viagem (km): "))
consumo_medio = float(input("Consumo médio (km/l): "))
preco_litro = float(input("Preço do litro (R$): "))
pedagios = float(input("Total de pedágios (R$): "))
numero_pessoas = int(input("Número de pessoas: "))
litros_necessarios = distancia / consumo_medio
custo_combustivel = litros_necessarios * preco_litro
custo_total = custo_combustivel + pedagios
custo_por_pessoa = custo_total / numero_pessoas
print()
print("Litros necessários:", round(litros_necessarios, 2))
print("Custo do combustível: R$", format(custo_combustivel, ".2f"))
print("Custo total da viagem: R$", format(custo_total, ".2f"))
print("Custo por pessoa: R$", format(custo_por_pessoa, ".2f"))
print("Tipo da distância:", type(distancia),
"| Tipo do número de pessoas:", type(numero_pessoas))
# Out:
# Distância da viagem (km): 6
# Consumo médio (km/l): 7
# Preço do litro (R$): 5
# Total de pedágios (R$): 4
# Número de pessoas: 3
#
# Litros necessários: 0.86
# Custo do combustível: R$ 4.29
# Custo total da viagem: R$ 8.29
# Custo por pessoa: R$ 2.76
# Tipo da distância: <class 'float'> | Tipo do número de pessoas: <class 'int'>

# %% [markdown]
# ### Questão 2: Crachá do estudante (1,0 ponto)
#
# Escreva um programa que leia o **primeiro nome** e o **sobrenome** do usuário (em duas chamadas separadas de
# `input`) e monte um crachá com as informações abaixo:
#
# 1. o nome completo (primeiro nome + espaço + sobrenome);
# 2. o nome completo em MAIÚSCULAS e em minúsculas;
# 3. o total de letras do nome completo, **sem contar o espaço**;
# 4. as iniciais em maiúsculo, separadas por ponto (por exemplo, `A.S.`);
# 5. um e-mail sugerido no formato `primeironome.sobrenome@edu.br`, todo em minúsculas;
# 6. uma linha decorativa de `=` com o mesmo comprimento do nome completo (use o operador `*` de strings);
# 7. uma verificação booleana: a letra `"a"` aparece no nome completo em minúsculas? (use o operador `in` e exiba o valor `True`/`False`).
#
# Exemplo:
#
# ```
# Primeiro nome: Ana
# Sobrenome: Silva
#
# =========
# Ana Silva
# ANA SILVA
# ana silva
# Total de letras: 8
# Iniciais: A.S.
# E-mail: ana.silva@edu.br
# Contém a letra 'a': True
# =========
# ```

# %%
primeiro_nome = input("Primeiro nome: ")
sobrenome = input("Sobrenome: ")

nome_completo = primeiro_nome + " " + sobrenome
nome_maiusculo = nome_completo.upper()
nome_minusculo = nome_completo.lower()
total_letras = len(nome_completo.replace(" ", ""))
iniciais = primeiro_nome[0].upper() + "." + sobrenome[0].upper() + "."
email = primeiro_nome.lower() + "." + sobrenome.lower() + "@edu.br"
contem_a = "a" in nome_minusculo
linha = "=" * len(nome_completo)

print()
print(linha)
print(nome_completo)
print(nome_maiusculo)
print(nome_minusculo)
print("Total de letras:", total_letras)
print("Iniciais:", iniciais)
print("E-mail:", email)
print("Contém a letra 'a':", contem_a)
print(linha)

# %% [markdown]
# ### Questão 3: Distância entre dois pontos (1,0 ponto)
#
# Usando a instrução `import` e o módulo `math`, escreva um programa que:
#
# 1. leia as coordenadas de dois pontos do plano: `x1`, `y1`, `x2` e `y2` (todos `float`);
# 2. calcule `dx` e `dy` como as diferenças **em valor absoluto** entre as coordenadas;
# 3. calcule a distância entre os pontos com a fórmula abaixo:
#
# $$distancia = \sqrt{dx^2 + dy^2}$$
#
# 4. calcule a área do círculo que tem essa distância como raio;
# 5. exiba `dx`, `dy`, a distância e a área, todos arredondados para 2 casas decimais com `round`.
#
# Exemplo:
#
# ```
# x1: 1
# y1: 2
# x2: 4
# y2: 6
#
# dx = 3.0
# dy = 4.0
# Distância entre os pontos: 5.0
# Área do círculo de raio 5.0: 78.54
# ```

# %%
import math

x1 = float(input("x1: "))
y1 = float(input("y1: "))
x2 = float(input("x2: "))
y2 = float(input("y2: "))

dx = abs(x2 - x1)
dy = abs(y2 - y1)

distancia = math.sqrt(dx ** 2 + dy ** 2)
area = math.pi * distancia ** 2
print()
print("dx =", round(dx, 2))
print("dy =", round(dy, 2))
print("Distância entre os pontos:", round(distancia, 2))
print("Área do círculo de raio", round(distancia, 2), ":", round(area, 2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1476/217213141.py in <cell line: 0>()
#       1 import math
#       2
# ----> 3 x1 = float(input("x1: "))
#       4 y1 = float(input("y1: "))
#       5 x2 = float(input("x2: "))
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ---
#
# ## Parte 2: Funções, encapsulamento e generalização (3,0 pontos)

# %% [markdown]
# ### Questão 4: Encapsulamento e refatoração (1,0 ponto)
#
# O código abaixo calcula e exibe a média de três alunos. Ele **funciona**, mas repete a mesma lógica três vezes:
#
# ```python
# nota1 = 7.0
# nota2 = 5.5
# nota3 = 9.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Ana:", round(media, 2))
#
# nota1 = 4.0
# nota2 = 6.5
# nota3 = 5.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Bruno:", round(media, 2))
#
# nota1 = 9.5
# nota2 = 8.0
# nota3 = 10.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Carla:", round(media, 2))
# ```
#
# Sua tarefa:
#
# **(a)** **Encapsule** essa lógica em uma função chamada `exibir_media(nome, nota1, nota2, nota3)`, que calcula a
# média das três notas e exibe a mensagem no mesmo formato. A função deve ter uma **docstring** descrevendo o que
# ela faz e o que significa cada parâmetro.
#
# **(b)** Chame a função três vezes para reproduzir exatamente a mesma saída do código original.
#
# **(c)** Na célula de texto indicada, explique com suas palavras: o que é **encapsulamento**, o que é
# **refatoração**, e por que a versão com função é melhor que a original.
#
# Saída esperada:
#
# ```
# Média de Ana: 7.17
# Média de Bruno: 5.17
# Média de Carla: 9.17
# ```

# %%
def exibir_media(nome, nota1, nota2, nota3):
    """Calcula e mostra a média de três notas de um aluno.

    nome: nome do aluno.
    nota1: primeira nota do aluno.
    nota2: segunda nota do aluno.
    nota3: terceira nota do aluno.
    """
    media = (nota1 + nota2 + nota3) / 3
    print("Média de", nome + ":", round(media, 2))


exibir_media("Ana", 7.0, 5.5, 9.0)
exibir_media("Bruno", 4.0, 6.5, 5.0)
exibir_media("Carla", 9.5, 8.0, 10.0)
# Out:
# Média de Ana: 7.17
# Média de Bruno: 5.17
# Média de Carla: 9.17

# %% [markdown]
# **(c) Sua explicação sobre encapsulamento e refatoração:**
#
# _(Encapsulamento é colocar uma determinada lógica dentro de uma função, deixando o código mais organizado e permitindo utilizar essa lógica sempre que necessário. Refatoração é modificar o código para deixá-lo mais organizado, simples e fácil de manter, sem mudar o resultado. A versão com função é melhor porque evita repetir o mesmo cálculo várias vezes e permite reutilizar a mesma função para diferentes alunos e notas.
# .)_

# %% [markdown]
# ### Questão 5: Generalização, parâmetros e variáveis locais (1,0 ponto)
#
# **(a)** Escreva uma função chamada `moldura(texto, caractere, largura)` que exibe um texto dentro de uma moldura.
# A função deve:
#
# - imprimir uma linha formada pela repetição de `caractere`, com a `largura` especificada;
# - imprimir o `texto` entre dois `caractere` (um no início e outro no fim da linha);
# - imprimir novamente a linha de fechamento.
#
# A função deve ter uma **docstring**. Note que ela **não retorna valor**, apenas exibe (retorna `None`).
#
# Exemplo:
#
# ```
# moldura("Trabalho 1", "*", 20)
# ```
#
# Saída:
#
# ```
# ********************
# * Trabalho 1
# ********************
# ```
#
# **(b)** Chame `moldura` **três vezes**, com textos, caracteres e larguras diferentes, mostrando que a função foi
# **generalizada** pelos parâmetros.

# %%
def moldura(texto, caractere, largura):
    """Mostra um texto dentro de uma moldura usando um caractere.

    texto: texto que será exibido dentro da moldura.
    caractere: caractere usado para formar a moldura.
    largura: quantidade de caracteres das linhas da moldura.
    """
    linha = caractere * largura
    print(linha)
    print(caractere, texto)
    print(linha)


moldura("Java", "*", 20)
moldura("Python", "#", 15)
moldura("Univali", "-", 25)
# Out:
# ********************
# * Java
# ********************
# ###############
# # Python
# ###############
# -------------------------
# - Univali
# -------------------------

# %% [markdown]
# ### Questão 6: Desenhando com `jupyturtle` (1,0 ponto)
#
# Não esqueça de baixar o módulo `jupyturtle` antes de resolver a questão.

# %% [markdown]
# **(a)** Escreva uma função chamada `poligono(lados, tamanho)` que desenhe um polígono regular com o número de lados e o comprimento de lado informados. A função deve ter docstring.
#
# **(b)** Escreva uma função chamada `flor(petalas, lados, tamanho)` que **reutilize** `poligono` para desenhar
# uma flor.
#
# **(c)** Faça três desenhos: um triângulo, um hexágono e uma flor.
#
# Exemplo:
#
# ```
# make_turtle()
# flor(8, 4, 30)
# ```

# %%
# !pip install jupyturtle
# Out:
# Collecting jupyturtle
#   Downloading jupyturtle-2024.4.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting ipython>=8 (from jupyturtle)
#   Downloading ipython-9.17.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting jupyter (from jupyturtle)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.13/dist-packages (from jupyturtle) (8.4.2)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=8->jupyturtle)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=8->jupyturtle)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /usr/local/lib/python3.13/dist-packages (from ipython>=8->jupyturtle) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /usr/local/lib/python3.13/dist-packages (from ipython>=8->jupyturtle) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.13/dist-packages (from ipython>=8->jupyturtle) (3.0.53)
# Collecting psutil>=7 (from ipython>=8->jupyturtle)
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pygments>=2.14.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=8->jupyturtle) (2.21.0)
# Collecting stack_data>=0.6.0 (from ipython>=8->jupyturtle)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=8->jupyturtle)
#   Downloading traitlets-5.16.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: notebook in /usr/local/lib/python3.13/dist-packages (from jupyter->jupyturtle) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.13/dist-packages (from jupyter->jupyturtle) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.13/dist-packages (from jupyter->jupyturtle) (7.17.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.13/dist-packages (from jupyter->jupyturtle) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.13/dist-packages (from jupyter->jupyturtle) (7.7.1)
# Collecting jupyterlab (from jupyter->jupyturtle)
#   Downloading jupyterlab-4.6.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.13/dist-packages (from pytest->jupyturtle) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.13/dist-packages (from pytest->jupyturtle) (26.3)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.13/dist-packages (from pytest->jupyturtle) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.18.2->ipython>=8->jupyturtle) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.6->ipython>=8->jupyturtle) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8->jupyturtle) (0.8.3)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=8->jupyturtle)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=8->jupyturtle)
#   Downloading asttokens-3.0.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=8->jupyturtle)
#   Downloading pure_eval-0.2.4-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel->jupyter->jupyturtle) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel->jupyter->jupyturtle) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from ipykernel->jupyter->jupyturtle) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel->jupyter->jupyturtle) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel->jupyter->jupyturtle) (6.5.7)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->jupyter->jupyturtle) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->jupyter->jupyturtle) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->jupyter->jupyturtle) (3.0.17)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.13/dist-packages (from jupyter-console->jupyter->jupyturtle) (5.9.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->jupyturtle)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jupyterlab->jupyter->jupyturtle) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.13/dist-packages (from jupyterlab->jupyter->jupyturtle) (3.1.6)
# Collecting jupyter-builder>=1.0.2 (from jupyterlab->jupyter->jupyturtle)
#   Downloading jupyter_builder-1.2.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->jupyturtle)
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from jupyterlab->jupyter->jupyturtle) (2.20.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->jupyter->jupyturtle)
#   Downloading jupyterlab_server-2.28.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.13/dist-packages (from jupyterlab->jupyter->jupyturtle) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->jupyturtle) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (5.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert->jupyter->jupyturtle) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook->jupyter->jupyturtle) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook->jupyter->jupyturtle) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook->jupyter->jupyturtle) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook->jupyter->jupyturtle) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook->jupyter->jupyturtle) (1.3.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->jupyturtle) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->jupyturtle) (1.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->jupyturtle) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->jupyturtle) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->jupyturtle) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->jupyturtle) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->jupyturtle) (0.16.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->jupyturtle) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->jupyturtle) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter->jupyturtle) (4.11.7)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (1.9.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook->jupyter->jupyturtle) (26.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.13/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle)
#   Downloading json5-0.15.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.13/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.13/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (2.32.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat>=5.7->nbconvert->jupyter->jupyturtle) (2.22.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert->jupyter->jupyturtle) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert->jupyter->jupyturtle) (4.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (0.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter->jupyturtle) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->jupyturtle) (2.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->jupyturtle) (2.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->jupyturtle) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.13/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->jupyturtle) (2026.3)
# Downloading jupyturtle-2024.4.1-py3-none-any.whl (7.5 kB)
# Downloading ipython-9.17.1-py3-none-any.whl (639 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.0/639.0 kB 33.9 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 74.5 MB/s eta 0:00:00
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 11.1 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading traitlets-5.16.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 4.0 MB/s eta 0:00:00
# Downloading jupyterlab-4.6.3-py3-none-any.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 55.4 MB/s eta 0:00:00
# Downloading asttokens-3.0.2-py3-none-any.whl (28 kB)
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading jupyter_builder-1.2.3-py3-none-any.whl (947 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 947.5/947.5 kB 41.3 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 5.9 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 4.5 MB/s eta 0:00:00
# Downloading pure_eval-0.2.4-py3-none-any.whl (11 kB)
# Downloading json5-0.15.0-py3-none-any.whl (36 kB)
# Installing collected packages: pure-eval, traitlets, psutil, json5, jedi, ipython-pygments-lexers, executing, async-lru, asttokens, stack_data, jupyter-builder, ipython, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, jupyturtle
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.17.1 which is incompatible.
# Successfully installed asttokens-3.0.2 async-lru-2.3.0 executing-2.2.1 ipython-9.17.1 ipython-pygments-lexers-1.1.1 jedi-0.20.0 json5-0.15.0 jupyter-1.1.1 jupyter-builder-1.2.3 jupyter-lsp-2.3.1 jupyterlab-4.6.3 jupyterlab-server-2.28.1 jupyturtle-2024.4.1 psutil-7.2.2 pure-eval-0.2.4 stack_data-0.6.3 traitlets-5.16.1

# %%
from jupyturtle import *


def poligono(lados, tamanho):
  """Desenha um polígono  com a quantidade de lados e tamanho falados pelo usuário.

  lados: número de lados do polígono.
  tamanho: comprimento de cada lado.
  """
  angulo = 360 / lados
  for i in range(lados):
    forward(tamanho)
    left(angulo)


def flor(petalas, lados, tamanho):
  """Desenha uma flor reutilizando a função poligono.

  petalas: quantidade de pétalas da flor.
  lados: quantidade de lados de cada pétala.
  tamanho: comprimento dos lados das pétalas.
  """
  angulo = 360 / petalas

  for i in range(petalas):
    poligono(lados, tamanho)
    left(angulo)

# %%
make_turtle()

poligono(3, 60)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 210,75 180,23 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
make_turtle()

poligono(6, 50)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200,75 225,31.7 200,-11.6 150,-11.6 125,31.7 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
make_turtle()

flor(8, 4, 30)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 180,75 180,45 150,45 150,75 171.2,53.8 150,32.6 128.8,53.8 150,75 150,45 120,45 120,75 150,75 128.8,53.8 107.6,75 128.8,96.2 150,75 120,75 120,105 150,105 150,75 128.8,96.2 150,117.4 171.2,96.2 150,75 150,105 180,105 180,75 150,75 171.2,96.2 192.4,75 171.2,53.8 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ---
#
# ## Parte 3: Expressões booleanas e condicionais (2,0 pontos)

# %% [markdown]
# ### Questão 7: Funções booleanas e operadores lógicos (1,0 ponto)
#
# **(a)** Escreva uma função chamada `eh_bissexto(ano)` que **retorne** `True` se o ano for bissexto e `False` caso contrário. Use os operadores `%`, `and`, `or` e `not` em uma **única expressão booleana** no `return`
# (não use `if`).
#
# **(b)** Escreva uma função chamada `eh_triangulo(a, b, c)` que retorne `True` se três medidas podem formar um
# triângulo. A condição é que cada lado seja **positivo** e que cada lado seja **menor** que a soma dos outros dois.
#
# **(c)** Usando `for i in range(...)`, exiba para os anos de **1996 a 2005** se cada um é bissexto ou não.
#
# **(d)** Teste `eh_triangulo` com pelo menos três combinações diferentes, exibindo o resultado de cada teste.
#
# Exemplo:
#
# ```
# 1996 é bissexto? True
# 1997 é bissexto? False
# ...
# 2000 é bissexto? True
# ...
# eh_triangulo(3, 4, 5) -> True
# eh_triangulo(1, 2, 10) -> False
# eh_triangulo(-1, 4, 5) -> False
# ```

# %%
def eh_bissexto(ano):
    """Retorna True se o ano for bissexto e False caso contrário."""
    return (ano % 400 == 0) or ((ano % 4 == 0) and not (ano % 100 == 0))


def eh_triangulo(a, b, c):
    """Retorna True se os três lados puderem formar um triângulo."""
    return (a > 0 and b > 0 and c > 0) and (a < b + c and b < a + c and c < a + b)


for i in range(1996, 2006):
    print(i, "é bissexto?", eh_bissexto(i))


print()
print("eh_triangulo(3, 4, 5) ->", eh_triangulo(3, 4, 5))
print("eh_triangulo(1, 2, 10) ->", eh_triangulo(1, 2, 10))
print("eh_triangulo(-1, 4, 5) ->", eh_triangulo(-1, 4, 5))
# Out:
# 1996 é bissexto? True
# 1997 é bissexto? False
# 1998 é bissexto? False
# 1999 é bissexto? False
# 2000 é bissexto? True
# 2001 é bissexto? False
# 2002 é bissexto? False
# 2003 é bissexto? False
# 2004 é bissexto? True
# 2005 é bissexto? False
#
# eh_triangulo(3, 4, 5) -> True
# eh_triangulo(1, 2, 10) -> False
# eh_triangulo(-1, 4, 5) -> False

# %% [markdown]
# ### Questão 8: Condicionais encadeadas e aninhadas (1,0 ponto)
#
# Escreva uma função chamada `classificar_imc(peso, altura)` que:
#
# 1. **valide os dados**: se `peso` **ou** `altura` for menor ou igual a zero, a função deve
#    retornar `None`, sem calcular nada;
# 2. caso os dados sejam válidos, calcule o IMC com a fórmula `imc = peso / altura ** 2`;
# 3. use uma **condicional encadeada** (`if`/`elif`/`else`) para **retornar** a classificação correspondente:
#
# | IMC | Classificação |
# |---|---|
# | menor que 18,5 | `"Abaixo do peso"` |
# | de 18,5 a 24,9 | `"Peso normal"` |
# | de 25,0 a 29,9 | `"Sobrepeso"` |
# | 30,0 ou mais | `"Obesidade"` |
#
# Depois, escreva um programa que leia o peso e a altura do usuário, chame a função e:
#
# - se o retorno for `None`, exiba a mensagem `"Dados inválidos: peso e altura devem ser positivos."`;
# - caso contrário, exiba o IMC arredondado com 2 casas decimais e a classificação.
#
# A função deve ter **docstring**.
#
# Exemplo:
#
# ```
# Peso (kg): 72.5
# Altura (m): 1.75
# IMC: 23.67 -> Peso normal
# ```
#
# ```
# Peso (kg): 70
# Altura (m): 0
# Dados inválidos: peso e altura devem ser positivos.
# ```

# %%
def classificar_imc(peso, altura):
    """
    Calcula o IMC e retorna o valor do IMC e sua classificação.
    Parâmetros:
        peso: peso da pessoa em quilogramas.
        altura: altura da pessoa em metros.
    Retorna:
        None se o peso ou a altura forem inválidos.
        Caso contrário, retorna o IMC e sua classificação.
    """
    if peso <= 0 or altura <= 0:
        return None
    imc = peso / (altura ** 2)
    if imc < 18.5:
        classificacao = "Abaixo do peso"
    elif imc < 25.0:
        classificacao = "Peso normal"
    elif imc < 30.0:
        classificacao = "Sobrepeso"
    else:
        classificacao = "Obesidade"

    return imc, classificacao

peso = float(input("Peso (kg): "))
altura = float(input("Altura (m): "))
resultado = classificar_imc(peso, altura)

if resultado is None:
    print("Dados inválidos: peso e altura devem ser positivos.")
else:
    imc, classificacao = resultado
    print("IMC:", format(imc, ".2f"), "->", classificacao)
# Out:
# Peso (kg): 72
# Altura (m): 1.86
# IMC: 20.81 -> Peso normal

# %% [markdown]
# ---
#
# ## Parte 4: Valores de retorno, `None` e docstrings (0,5 ponto)

# %% [markdown]
# ### Questão 9: `print` não é `return` (0,5 ponto)
#
# **(a)** Escreva duas funções, ambas com docstring:
#
# - `mostrar_dobro(numero)`: **exibe** o dobro do número com `print` e **não retorna nada**;
# - `calcular_dobro(numero)`: **retorna** o dobro do número, sem exibir nada.
#
# **(b)** Execute e observe os quatro comandos abaixo, mantendo as saídas visíveis:
#
# ```python
# mostrar_dobro(5)
# print(mostrar_dobro(5))
# calcular_dobro(5)
# print(calcular_dobro(5))
# ```
#
# **(c)** Mostre que o valor de retorno pode ser usado em uma expressão, por exemplo:
# `print(calcular_dobro(5) + calcular_dobro(10))`. Tente fazer o mesmo com `mostrar_dobro` e copie o erro em um
# comentário.
#
# **(d)** Na célula de texto indicada, responda:
#
# 1. Por que `print(mostrar_dobro(5))` exibe `None`?
# 2. Qual das duas funções é mais reaproveitável e por quê?
# 3. Para que serve uma **docstring** e em que ela se diferencia de um comentário comum? Cite um exemplo de ferramenta que **lê** a docstring das suas funções.

# %%
def mostrar_dobro(numero):
    """Exibe o dobro de um número usando print.

    numero: número que terá seu dobro exibido.
    """
    print(numero * 2)


def calcular_dobro(numero):
    """Retorna o dobro de um número.

    numero: número que terá seu dobro calculado.
    """
    return numero * 2


mostrar_dobro(5)
print(mostrar_dobro(5))
calcular_dobro(5)
print(calcular_dobro(5))
# Out:
# 10
# 10
# None
# 10

# %%
print(calcular_dobro(5) + calcular_dobro(10))

# O comando abaixo gera um erro porque mostrar_dobro não retorna um valor:
# print(mostrar_dobro(5) + mostrar_dobro(10))
#
# Erro esperado:
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %% [markdown]
# **(d) Suas respostas:**
#
# 1. _(print(mostrar_dobro(5)) exibe None porque a função mostrar_dobro apenas mostra o resultado com print e não possui um return. Quando uma função não retorna um valor, o Python retorna None automaticamente.)_
# 2. _(A função calcular_dobro é mais reaproveitável porque seu resultado pode ser armazenado em uma variável, usado em cálculos e passado para outras funções. Já mostrar_dobro serve apenas para exibir o resultado.)_
# 3. _(Uma docstring é um texto dentro da função que explica o que ela faz e quais são seus parâmetros. Ela se diferencia de um comentário porque pode ser acessada pelo próprio Python. Uma ferramenta que lê docstrings é o help(), por exemplo, usando help(calcular_dobro).)_

# %% [markdown]
# ---
#
# ## Parte 5: Plano de desenvolvimento e desenvolvimento incremental (1,5 ponto)

# %% [markdown]
# ### Questão 10: Boletim da turma (1,5 ponto)
#
# Escreva um programa que gere o boletim de uma turma.
#
# O programa deve:
#
# 1. ler a quantidade de alunos (`int`);
# 2. para cada aluno:
#    - ler o nome (`str`) e três notas (`float`);
#    - calcular a média com uma função `media_notas(nota1, nota2, nota3)` que **retorna** o valor;
#    - obter a situação com uma função `situacao(media)` que **retorna** `"Aprovado"` (média maior ou igual a 7),
#      `"Recuperação"` (média maior ou igual a 4 e menor que 7) ou `"Reprovado"` (média menor que 4);
#    - exibir uma linha do boletim com o nome, a média (1 casa decimal) e a situação;
# 3. ao final, exibir:
#    - a média geral da turma (2 casas decimais);
#    - a quantidade e o **percentual** de aprovados;
#    - o nome do aluno com a maior média.
#
# Todas as funções devem ter **docstring**.
#
# Exemplo:
#
# ```
# Quantos alunos? 3
#
# Aluno 1 - nome: Ana
# Nota 1: 7
# Nota 2: 5.5
# Nota 3: 9
# Aluno 2 - nome: Bruno
# Nota 1: 4
# Nota 2: 3
# Nota 3: 2
# Aluno 3 - nome: Carla
# Nota 1: 9.5
# Nota 2: 8
# Nota 3: 10
#
# ===== BOLETIM =====
# Ana: 7.2 - Aprovado
# Bruno: 3.0 - Reprovado
# Carla: 9.2 - Aprovado
# ===================
# Média geral da turma: 6.44
# Aprovados: 2 de 3 (66.67%)
# Melhor média: Carla (9.17)
# ```
#
# **(a) Plano de desenvolvimento:** *antes* de programar, descreva na célula de
# texto abaixo o seu plano: quais funções você vai criar, quais parâmetros cada uma recebe, o que cada uma retorna e em que ordem você vai construir o programa.
#
# **(b) Desenvolvimento incremental:** escreva o programa em etapas, testando cada uma. Nas células de código indicadas, mantenha as **três versões**:
#
# - **Versão 1:** apenas as funções `media_notas` e `situacao`, testadas com valores fixos (sem `input`).
# - **Versão 2:** o laço que lê os alunos e exibe as linhas do boletim.
# - **Versão 3:** a versão final, com as estatísticas do final do boletim.
#
# **(c)** Ao final, comente na célula de texto o que mudou de uma versão para a outra e qual erro você encontrou (e corrigiu) durante o processo.

# %% [markdown]
# **(a) Seu plano de desenvolvimento:**
#
# _(Primeiro vou criar a função media_notas, que receberá três notas e retornará a média. Depois vou criar a função situacao, que receberá a média e retornará Aprovado, Recuperação ou Reprovado. Na Versão 1 vou testar essas duas funções com valores fixos. Na Versão 2 vou criar o laço para ler a quantidade de alunos, seus nomes e suas notas e exibir o boletim. Na Versão 3 vou acrescentar as estatísticas finais: média geral da turma, quantidade e percentual de aprovados e aluno com a maior média.)_

# %%
def media_notas(nota1, nota2, nota3):
    """Calcula e retorna a média de três notas."""
    return (nota1 + nota2 + nota3) / 3


def situacao(media):
    """Retorna a situação do aluno de acordo com sua média."""
    if media >= 7:
        return "Aprovado"
    elif media >= 4:
        return "Recuperação"
    else:
        return "Reprovado"


media_teste = media_notas(7.0, 5.5, 9.0)

print("Média:", round(media_teste, 2))
print("Situação:", situacao(media_teste))
# Out:
# Média: 7.17
# Situação: Aprovado

# %%
def media_notas(nota1, nota2, nota3):
    """Calcula e retorna a média de três notas."""
    return (nota1 + nota2 + nota3) / 3


def situacao(media):
    """Retorna a situação do aluno de acordo com sua média."""
    if media >= 7:
        return "Aprovado"
    elif media >= 4:
        return "Recuperação"
    else:
        return "Reprovado"


quantidade_alunos = int(input("Quantos alunos? "))

print()
print("===== BOLETIM =====")

for i in range(quantidade_alunos):
    print()
    print("Aluno", i + 1)

    nome = input("Nome: ")
    nota1 = float(input("Nota 1: "))
    nota2 = float(input("Nota 2: "))
    nota3 = float(input("Nota 3: "))

    media = media_notas(nota1, nota2, nota3)
    resultado = situacao(media)

    print(nome + ":", format(media, ".1f"), "-", resultado)

print("===================")
# Out:
# Quantos alunos? 1
#
# ===== BOLETIM =====
#
# Aluno 1
# Nome: joao
# Nota 1: 7
# Nota 2: 8
# Nota 3: 4
# joao: 6.3 - Recuperação
# ===================

# %%
def media_notas(nota1, nota2, nota3):
    """Calcula e retorna a média de três notas."""
    return (nota1 + nota2 + nota3) / 3


def situacao(media):
    """Retorna a situação do aluno de acordo com sua média."""
    if media >= 7:
        return "Aprovado"
    elif media >= 4:
        return "Recuperação"
    else:
        return "Reprovado"


quantidade_alunos = int(input("Quantos alunos? "))

nomes = []
medias = []
situacoes = []

for i in range(quantidade_alunos):
    print()
    print("Aluno", i + 1, "-")

    nome = input("Nome: ")
    nota1 = float(input("Nota 1: "))
    nota2 = float(input("Nota 2: "))
    nota3 = float(input("Nota 3: "))

    media = media_notas(nota1, nota2, nota3)
    resultado = situacao(media)

    nomes.append(nome)
    medias.append(media)
    situacoes.append(resultado)


print()
print("===== BOLETIM =====")

for i in range(quantidade_alunos):
    print(nomes[i] + ":", format(medias[i], ".1f"), "-", situacoes[i])

print("===================")

media_geral = sum(medias) / quantidade_alunos

quantidade_aprovados = 0

for resultado in situacoes:
    if resultado == "Aprovado":
        quantidade_aprovados += 1

percentual_aprovados = (quantidade_aprovados / quantidade_alunos) * 100

indice_maior_media = 0

for i in range(1, quantidade_alunos):
    if medias[i] > medias[indice_maior_media]:
        indice_maior_media = i

print("Média geral da turma:", format(media_geral, ".2f"))
print("Aprovados:", quantidade_aprovados, "de", quantidade_alunos,
      "(", format(percentual_aprovados, ".2f") + "%)")
print("Melhor média:", nomes[indice_maior_media],
      "(", format(medias[indice_maior_media], ".2f") + ")")
# Out:
# Quantos alunos? 1
#
# Aluno 1 -
# Nome: joao
# Nota 1: 6
# Nota 2: 7
# Nota 3: 4
#
# ===== BOLETIM =====
# joao: 5.7 - Recuperação
# ===================
# Média geral da turma: 5.67
# Aprovados: 0 de 1 ( 0.00%)
# Melhor média: joao ( 5.67)

# %% [markdown]
# **(c) O que mudou entre as versões e quais erros você corrigiu:**
#
# Na versão 1, eu fiz as funções media_notas e situacao e testei elas com alguns valores fixos para ver se estavam funcionando. Na versão 2, colequei o laço pra poder cadastrar vários alunos, informar as notas e mostrar o boletim de cada um. Na versão 3 acrescentei as estatísticas finais, como a média geral da turma, aporcentagem de alunos aprovados e qual aluno teve a maior média.
#
# Um problema que poderia acontecer durante a escrita do código seria não guardar as médias dos alunos. Se isso acontecesse, não serua possível calcular a média geral nem descobir quem teve a maior média. Para resolver isso, eu usei listas para guardar os nomes, as médias e as situações dos alunos.

# %% [markdown]
# ---
#
# ## Declaração de uso de assistentes de IA
#
# Preencha honestamente:
#
# - **Usei assistente de IA neste trabalho?** ( ) Não  (x ) Sim
# - **Em quais questões e para quê?** _(Utillizei a IA para me ajudar a expressar minhas ideais ao explica o exercicio, melhorando meu vocabulario)_
# - **Declaro que sou capaz de explicar cada linha do código entregue:** (x ) Sim
#
# ---
#
# **Happy Coding! 🐍**
